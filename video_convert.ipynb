# %%
import subprocess
import os
import glob

def convert_mp4_to_mp3(input_file, output_file):
    ffmpeg_cmd = [
        'ffmpeg',
        '-i', input_file,
        '-vn',
        '-acodec', 'libmp3lame',
        '-b:a', '192k',
        output_file
    ]
    subprocess.run(ffmpeg_cmd, check=True)

golden_set_dir = "golden_set"

for folder in sorted(os.listdir(golden_set_dir)):
    folder_path = os.path.join(golden_set_dir, folder)
    if not os.path.isdir(folder_path):
        continue
    mp4_files = sorted(glob.glob(os.path.join(folder_path, "*.mp4")))
    if not mp4_files:
        continue
    input_file = mp4_files[0]
    output_file = os.path.splitext(input_file)[0] + ".mp3"
    convert_mp4_to_mp3(input_file, output_file)
# Out:
# ffmpeg version 9.0.1 Copyright (c) 2000-2026 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.6.4.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/9.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gpl --enable-libsvtav1 --enable-libopus --enable-libx264 --enable-libmp3lame --enable-libdav1d --enable-libvmaf --enable-libvpx --enable-libx265 --enable-openssl --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      61.  1.101 / 61.  1.101
#   libavcodec     63.  1.101 / 63.  1.101
#   libavformat    63.  1.101 / 63.  1.101
#   libavdevice    63.  1.101 / 63.  1.101
#   libavfilter    12.  1.101 / 12.  1.101
#   libswscale     10.  1.101 / 10.  1.101
#   libswresample   7.  1.101 /  7.  1.101
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'golden_set/video_1/3 Easy Mushroom Houses! + Building Circles in Minecraft - Spoookily (1080p).mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf62.12.102
#   Duration: 00:09:14.24, start: 0.000000, bitrate: 3370 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 3235 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# File 'golden_set/video_1/3 Easy Mushroom Houses! + Building Circles in Minecraft - Spoookily (1080p).mp3' already exists. Overwrite? [y/N]
